# %%
from object_detection import run_viewer
from understanding import interpret_image

# %%
t = run_viewer("resources/street.png")
# Out:
# image 1/1 /Users/jscheltema/Documents/Personal/PAL/perception/vision/resources/street.png: 448x640 14 persons, 1 car, 32.4ms
# Speed: 1.6ms preprocess, 32.4ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
# Selected: person (0.85) at (523, 247, 618, 480)
# Description: Based on a visual analysis of the image, here is the threat level assessment:
#
# **Overall Assessment: Low Threat**
#
# The image depicts a relatively calm, everyday scene in a public setting. There are no immediate signs of active hostility, danger, or weapon possession.
#
# **Key Observations:**
#
# *   **Foreground Subject:** The primary subject (a woman) is dressed casually in a white cardigan and striped dress. Her body language appears calm; she is standing or walking with her hand near her face, possibly holding a phone or adjusting something, but there is no aggressive posture.
# ...

# %%
test = interpret_image(t)

# %%
test
# Out:
# 'A woman with short hair walks on a sidewalk wearing a fluffy white cardigan, blue-and-white striped skirt, and white sneakers. She touches her mouth.'
