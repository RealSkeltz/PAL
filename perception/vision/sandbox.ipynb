# %%
from ollama import chat

response = chat(
    model='moondream:1.8b',
    messages=[{'role': 'user', 'content': 'whats up'}],
)
print(response.message.content)
# Out:
# The image shows a person wearing a white shirt and black pants standing in front of a building. The person is positioned on the left side of the frame, while the building occupies most of the right side. There are no other people or objects visible in the scene.

# %%
image = cv2.imread("resources/street.png")
t = interpret_image_md(image)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 image = cv2.imread("resources/street.png")
# ----> 2 t = interpret_image_md(image)
#
# Cell In[2], line 9, in interpret_image_md(crop)
#       7 def interpret_image_md(crop):
#       8     image = Image.fromarray(cv2.cvtColor(crop, cv2.COLOR_BGR2RGB))
# ----> 9     result = model.query(image, "Describe what you see in one sentence.")["answer"]
#      10     return result
#
# File ~/Library/Caches/pypoetry/virtualenvs/pal-5szAi3Ow-py3.12/lib/python3.12/site-packages/moondream/cloud_vl.py:158, in CloudVL.query(self, image, question, stream, settings, reasoning)
#     155 if stream:
#     156     return {"answer": self._stream_response(req)}
# --> 158 with urllib.request.urlopen(req) as response:
#     159     result = json.loads(response.read().decode("utf-8"))
# ...

# %%
import moondream as md
print(type(md.vl(model="/Users/jscheltema/Documents/Personal/PAL/moondream-0_5b-int8.mf")))
# Out:
# <class 'moondream.cloud_vl.CloudVL'>

# %%
test
# Out:
# 'A woman with short hair walks on a sidewalk wearing a fluffy white cardigan, blue-and-white striped skirt, and white sneakers. She touches her mouth.'
